# %%
import numpy as np
from lorenz.lorenz import Lorenz
from lorenz.plot_lorenz import plot_lorenz3D, plot_lorenz2D, animate_lorenz

# %%
lorenz = Lorenz(initial_state=(1.0, 1.0, 1.0))
lorenz.solve()
# plot_lorenz(lorenz)
animate_lorenz(lorenz, "lorenz_attractor.gif")
# plot_lorenz2D(lorenz)
# Out:
# MovieWriter imagemagick unavailable; using Pillow instead.
